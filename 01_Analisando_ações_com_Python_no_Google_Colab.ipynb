# %% [markdown]
# <a href="https://colab.research.google.com/github/WesleyCastilho/Projeto-Investimento/blob/master/01_Analisando_a%C3%A7%C3%B5es_com_Python_no_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 - Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
yf.pdr_override()

# %% [markdown]
# # Obtendo os dados do Mercado

# %%
ibov = web.get_data_yahoo('^BVSP')

# %%
ibov.tail()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2021-04-26  120534.0  121393.0  119860.0  120595.0   120595.0   7095300
# 2021-04-27  120595.0  121012.0  119003.0  119388.0   119388.0   8362300
# 2021-04-28  119392.0  121276.0  119392.0  121053.0   121053.0   9081500
# 2021-04-29  121053.0  121498.0  119703.0  120066.0   120066.0   8500200
# 2021-04-30  120064.0  120125.0  118894.0  118894.0   118894.0  11093200

# %%
ibov["Close"].plot(figsize=(22,8))

# %% [markdown]
# # Pegando dados do Banco Inter

# %%
bidi = web.get_data_yahoo('BIDI4.SA')

# %%
bidi["Close"].plot(figsize=(22,8))
